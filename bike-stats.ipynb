# %% [markdown]
# # Lab 06: Aggregate Analysis - Bike Stats - Jay Adams

# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
df1 = pd.read_csv('data/cycle-share-dataset/station.csv')
df2 = pd.read_csv('data/cycle-share-dataset/trip.csv', error_bad_lines=False).drop_duplicates()
df3 = pd.read_csv('data/cycle-share-dataset/weather.csv')
# Out:
# b'Skipping line 50794: expected 12 fields, saw 20\n'

# %%
df1.head()
# Out:
#   station_id                    name        lat        long install_date  \
# 0      BT-01      3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1      BT-03       2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
# 2      BT-04  6th Ave & Blanchard St  47.616094 -122.341102   10/13/2014
# 3      BT-05  2nd Ave & Blanchard St  47.613110 -122.344208   10/13/2014
# 4     CBD-03      7th Ave & Union St  47.610731 -122.332447   10/13/2014
#
#    install_dockcount modification_date  current_dockcount decommission_date
# 0                 18               NaN                 18               NaN
# 1                 16               NaN                 16               NaN
# 2                 16               NaN                 16               NaN
# 3                 14               NaN                 14               NaN
# 4                 20               NaN                 20               NaN

# %%
df2.head()
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 2  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 3  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 4  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype  gender  birthyear
# ...

# %%
df3.head()
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
# 3  10/16/2014                 71                61.0                52
# 4  10/17/2014                 64                60.0                57
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
# 3               49               46              42            83
# 4               55               51              41            87
#
#    Mean_Humidity  Min_Humidity   ...    Mean_Sea_Level_Pressure_In  \
# 0             68            46   ...                         29.79
# ...

# %% [markdown]
# ## What is the average trip duration for a borrowed bicycle?

# %%
trip_duration = np.mean(df2['tripduration'])
trip_duration
# Out:
# 1202.6122102556499

# %% [markdown]
# ## What's the most common age of a bicycle-sharer?

# %%
trip_age = np.mean(df2['birthyear'])
difference = 2018 - trip_age
difference
# Out:
# 38.120259702942576

# %% [markdown]
# ## Given all the weather data here, find the average precipitation per month, and the median precipitation.

# %%
df3['DATE'] = pd.to_datetime(df3['Date'], errors='coerce')
df3['MONTH'] = df3['DATE'].dt.month
wea_avg = pd.DataFrame(df3['Precipitation_In'].groupby(df3.MONTH).mean())
wea_avg
# Out:
#        Precipitation_In
# MONTH
# 1              0.143548
# 2              0.168421
# 3              0.156935
# 4              0.051333
# 5              0.012419
# 6              0.030500
# 7              0.012097
# 8              0.018226
# 9              0.041000
# 10             0.189000
# 11             0.187833
# 12             0.236290

# %% [markdown]
# ## What’s the average number of bikes at a given bike station?

# %%
pd.DataFrame(df1['current_dockcount']).mean()
# Out:
# current_dockcount    16.517241
# dtype: float64

# %% [markdown]
# ## When a bike station is modified, is it more likely that it’ll lose bikes or gain bikes? How do you know?

# %%
pd.DataFrame(df1['install_dockcount']).mean()
# 17.58
#17.58 > 16.51 - lose bikes
# Out:
# install_dockcount    17.586207
# dtype: float64

# %% [markdown]
# ## Come up with 3 more questions that can be answered with this data set.

# %% [markdown]
# ## Days that hit the max temp

# %%
pd.DataFrame(df3[['Date', 'Max_Temperature_F']].sort_values('Max_Temperature_F', ascending=False)).head()
# Out:
#           Date  Max_Temperature_F
# 279  7/19/2015                 98
# 676  8/19/2016                 95
# 263   7/3/2015                 93
# 291  7/31/2015                 93
# 682  8/25/2016                 93

# %% [markdown]
# ## What is the average temp across the data

# %%
df3['Mean_Temperature_F'].mean()
# Out:
# 56.5843023255814

# %% [markdown]
# ## What are the most popular stations

# %%
pop_station = pd.DataFrame(df1[['station_id', 'name', 'current_dockcount']])
pop_station.nlargest(10, 'current_dockcount')
# Out:
#    station_id                                               name  \
# 17      CH-08             Cal Anderson Park / 11th Ave & Pine St
# 22     DPD-03  Children's Hospital / Sandpoint Way NE & 40th ...
# 52      WF-01                    Pier 69 / Alaskan Way & Clay St
# 4      CBD-03                                 7th Ave & Union St
# 6      CBD-05                                1st Ave & Marion St
# 8      CBD-07                     City Hall / 4th Ave & James St
# 12      CH-02                     E Harrison St & Broadway Ave E
# 27      FH-04      Seattle University / E Columbia St & 12th Ave
# 31     SLU-01                         REI / Yale Ave N & John St
# 35     SLU-15                             Westlake Ave & 6th Ave
#
#     current_dockcount
# 17                 26
# 22                 24
# 52                 24
# 4                  20
# 6                  20
# 8                  20
# 12                 20
# 27                 20
# 31                 20
# ...
